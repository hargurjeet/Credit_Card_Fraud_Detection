# %% [markdown]
# <a href="https://colab.research.google.com/github/hargurjeet/Credit_Card_Fraud_Detection/blob/main/Credit_card_fraud_detection_Starter_code_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Credit Card Fraud Detection
#
# In this project you will predict fraudulent credit card transactions with the help of Machine learning models. Please import the following libraries to get started.

# %%
# !pip install gitpython
# Out:
# Collecting gitpython
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.4 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.6 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.11 gitpython-3.1.40 smmap-5.0.1

# %%
import numpy as np
import pandas as pd
from git import Repo
import zipfile
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from imblearn.over_sampling import SMOTE, ADASYN
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler
from sklearn.datasets import make_classification
from collections import Counter
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import f1_score
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold

# %%
# Clone the github repository
git_url = 'https://github.com/hargurjeet/Credit_Card_Fraud_Detection.git'
Repo.clone_from(git_url, '/content/Credit_Card_Fraud_Dataset')
# Out:
# <git.repo.base.Repo '/content/Credit_Card_Fraud_Dataset/.git'>

# %%
# Unzip the csv file
with zipfile.ZipFile('/content/Credit_Card_Fraud_Dataset/creditcard.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Credit_Card_Fraud_Dataset/')

# %% [markdown]
# ## Exploratory data analysis

# %%
df = pd.read_csv('/content/Credit_Card_Fraud_Dataset/creditcard.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
#observe the different feature type present in the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# Here we will observe the distribution of our classes

# %%
classes=df['Class'].value_counts()
normal_share=classes[0]/df['Class'].count()*100
fraud_share=classes[1]/df['Class'].count()*100
print(classes)
print()
print('Normal Share in precentage', normal_share)
print()
print('Fraud Share in precentage', fraud_share)
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64
#
# Normal Share in precentage 99.82725143693798
#
# Fraud Share in precentage 0.1727485630620034

# %%
# Create a bar plot for the number and percentage of fraudulent vs non-fraudulent transcations
ax = sns.barplot(x=df["Class"], y = df['Class'].value_counts())

# Add labels to the x and y axes
ax.set_xlabel("Class")
ax.set_ylabel("Class Count")

# Show the plot
plt.show()

# %%
# Create a scatter plot to observe the distribution of classes with time
sns.scatterplot(x=df["Class"], y= df['Time'])
plt.title("Class Vs Time")
plt.show()

# %%
# Create a scatter plot to observe the distribution of classes with Amount
sns.scatterplot(x=df["Class"], y= df['Amount'])
plt.title('Class Vs Amount')
plt.show()

# %%
# Drop unnecessary columns
X = df.drop('Class', axis=1)

# %% [markdown]
# ### Splitting the data into train & test data

# %%
y= df['Class']

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ##### Preserve X_test & y_test to evaluate on the test data once you build the model

# %%
print(np.sum(y))
print(np.sum(y_train))
print(np.sum(y_test))
# Out:
# 492
# 356
# 136

# %% [markdown]
# ### Plotting the distribution of a variable

# %%
# plot the histogram of a variable from the dataset to see the skewness
X_train.hist(figsize=(15, 14))
plt.show();

# %% [markdown]
# ### If there is skewness present in the distribution use:
# - <b>Power Transformer</b> package present in the <b>preprocessing library provided by sklearn</b> to make distribution more gaussian

# %%
# - Apply : preprocessing.PowerTransformer(copy=False) to fit & transform the train & test data
pt = PowerTransformer()
X_transformed = pt.fit_transform(X_train)

# %%
X_train_pt = pd.DataFrame(X_transformed, columns=X_train.columns)

# %%
# plot the histogram of a variable from the dataset again to see the result
X_train_pt.hist(figsize=(15, 14))
plt.show();

# %% [markdown]
# ## Model Building with imbalance Classes
# - Build different models on the imbalanced dataset and see the result

# %% [markdown]
# #### perfom cross validation on the X_train & y_train to create:
# - X_train_cv
# - X_test_cv
# - y_train_cv
# - y_test_cv

# %%
from sklearn.model_selection import train_test_split

# Assuming X_train and y_train are your training data

# Perform train-test split for cross-validation
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a logistic regression model
model = LogisticRegression(solver='lbfgs', max_iter=1000, random_state=42)
param_grid = {'C': [0.001, 0.01, 0.1, 1, ], }


# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='f1_macro')
grid_search.fit(X_train, y_train)


# Train a new model with the best hyperparameters
best_model = grid_search.best_estimator_
best_model.fit(X_train, y_train)

# Evaluate the model using test dataset
y_pred = best_model.predict(X_test)
result = f1_score(y_test, y_pred)
print(("F1 Score: %.3f") % (result))
# Out:
# F1 Score: 0.699

# %%
# Print the classification report
predicted_labels = cross_val_predict(best_model, X, y, cv=5)
report = classification_report(y, predicted_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    284315
#            1       0.23      0.63      0.34       492
#
#     accuracy                           1.00    284807
#    macro avg       0.62      0.81      0.67    284807
# weighted avg       1.00      1.00      1.00    284807

# %% [markdown]
# #### Similarly explore other algorithms by building models like:
# - KNN
# - SVM
# - Decision Tree
# - Random Forest
# - XGBoost

# %% [markdown]
# #### KNN

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_neighbors': [3, 5,],
              'weights': ['uniform']}

# Create a KNN classifier
knn = KNeighborsClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(knn, param_grid, scoring='f1', verbose=10)

# Fit the model to the training data
grid_search.fit(X_train, y_train)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)

# elapsed_time = grid_search.cv_results_['mean_fit_time'].sum() + grid_search.cv_results_['mean_score_time'].sum()
# print('Time Consumed for execution', elapsed_time)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 1/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.179 total time= 1.0min
# [CV 2/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 2/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.105 total time=  46.6s
# [CV 3/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 3/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.128 total time=  47.5s
# [CV 4/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 4/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.080 total time=  45.9s
# [CV 5/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 5/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.103 total time=  46.7s
# [CV 1/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 1/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.080 total time=  44.5s
# [CV 2/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 2/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.081 total time=  44.5s
# [CV 3/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 3/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.081 total time=  44.6s
# [CV 4/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 4/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.027 total time=  45.7s
# [CV 5/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 5/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.052 total time=  45.8s
# Best Estimator: KNeighborsClassifier(n_neighbors=3)
# Best F1 Score: 0.1191039136302294
# F1 Score on Test Data: 0.21052631578947367
# CPU times: user 15min 10s, sys: 3.14 s, total: 15min 13s
# Wall time: 9min 51s

# %% [markdown]
# #### SVM

# %%
# %%time
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'C': [0.1, 1],
              'kernel': ['rbf']}

# Create an SVM classifier
svc = svm.SVC()

# Create GridSearchCV
grid_search = GridSearchCV(svc, param_grid, scoring='f1', verbose=10)

# Fit the model to the training data
grid_search.fit(X_train, y_train)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START C=0.1, kernel=rbf...........................................
# [CV 1/5; 1/2] END ............C=0.1, kernel=rbf;, score=0.000 total time=   9.4s
# [CV 2/5; 1/2] START C=0.1, kernel=rbf...........................................
# [CV 2/5; 1/2] END ............C=0.1, kernel=rbf;, score=0.000 total time=   8.3s
# [CV 3/5; 1/2] START C=0.1, kernel=rbf...........................................
# [CV 3/5; 1/2] END ............C=0.1, kernel=rbf;, score=0.000 total time=   9.0s
# [CV 4/5; 1/2] START C=0.1, kernel=rbf...........................................
# [CV 4/5; 1/2] END ............C=0.1, kernel=rbf;, score=0.000 total time=   9.8s
# [CV 5/5; 1/2] START C=0.1, kernel=rbf...........................................
# [CV 5/5; 1/2] END ............C=0.1, kernel=rbf;, score=0.000 total time=   7.6s
# [CV 1/5; 2/2] START C=1, kernel=rbf.............................................
# [CV 1/5; 2/2] END ..............C=1, kernel=rbf;, score=0.000 total time=   9.7s
# [CV 2/5; 2/2] START C=1, kernel=rbf.............................................
# [CV 2/5; 2/2] END ..............C=1, kernel=rbf;, score=0.000 total time=  10.9s
# [CV 3/5; 2/2] START C=1, kernel=rbf.............................................
# [CV 3/5; 2/2] END ..............C=1, kernel=rbf;, score=0.000 total time=   9.0s
# [CV 4/5; 2/2] START C=1, kernel=rbf.............................................
# [CV 4/5; 2/2] END ..............C=1, kernel=rbf;, score=0.000 total time=  10.1s
# [CV 5/5; 2/2] START C=1, kernel=rbf.............................................
# [CV 5/5; 2/2] END ..............C=1, kernel=rbf;, score=0.000 total time=   9.9s
# Best Estimator: SVC(C=0.1)
# Best F1 Score: 0.0
# F1 Score on Test Data: 0.0
# CPU times: user 1min 48s, sys: 1.97 s, total: 1min 50s
# Wall time: 1min 50s

# %% [markdown]
# #### Random Forest

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_estimators': [50, 100, 200],
              'max_depth': [5, 10]}

# Create a Random Forest classifier
rf = RandomForestClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(rf, param_grid, scoring='f1', verbose=10)

# Fit the model to the training data
grid_search.fit(X_train, y_train)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)
print("F1 Score on Test Data:", f1_test)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 1/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.813 total time=  29.2s
# [CV 2/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 2/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.733 total time=  29.0s
# [CV 3/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 3/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.837 total time=  29.0s
# [CV 4/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 4/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.842 total time=  28.9s
# [CV 5/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 5/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.857 total time=  29.4s
# [CV 1/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 1/5; 2/6] END max_depth=5, n_estimators=100;, score=0.813 total time=  59.0s
# [CV 2/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 2/5; 2/6] END max_depth=5, n_estimators=100;, score=0.739 total time=  59.2s
# [CV 3/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 3/5; 2/6] END max_depth=5, n_estimators=100;, score=0.819 total time=  58.1s
# [CV 4/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 4/5; 2/6] END max_depth=5, n_estimators=100;, score=0.824 total time= 1.0min
# [CV 5/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 5/5; 2/6] END max_depth=5, n_estimators=100;, score=0.844 total time=  59.2s
# [CV 1/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 1/5; 3/6] END max_depth=5, n_estimators=200;, score=0.813 total time= 1.9min
# [CV 2/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 2/5; 3/6] END max_depth=5, n_estimators=200;, score=0.744 total time= 1.9min
# [CV 3/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 3/5; 3/6] END max_depth=5, n_estimators=200;, score=0.816 total time= 1.9min
# [CV 4/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 4/5; 3/6] END max_depth=5, n_estimators=200;, score=0.836 total time= 1.9min
# [CV 5/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 5/5; 3/6] END max_depth=5, n_estimators=200;, score=0.859 total time= 2.0min
# [CV 1/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 1/5; 4/6] END max_depth=10, n_estimators=50;, score=0.844 total time=  55.6s
# [CV 2/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 2/5; 4/6] END max_depth=10, n_estimators=50;, score=0.787 total time=  55.4s
# [CV 3/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 3/5; 4/6] END max_depth=10, n_estimators=50;, score=0.844 total time=  55.0s
# [CV 4/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 4/5; 4/6] END max_depth=10, n_estimators=50;, score=0.838 total time=  55.3s
# [CV 5/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 5/5; 4/6] END max_depth=10, n_estimators=50;, score=0.874 total time=  54.6s
# [CV 1/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 1/5; 5/6] END max_depth=10, n_estimators=100;, score=0.819 total time= 1.8min
# [CV 2/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 2/5; 5/6] END max_depth=10, n_estimators=100;, score=0.787 total time= 1.8min
# [CV 3/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 3/5; 5/6] END max_depth=10, n_estimators=100;, score=0.859 total time= 1.8min
# [CV 4/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 4/5; 5/6] END max_depth=10, n_estimators=100;, score=0.853 total time= 1.9min
# [CV 5/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 5/5; 5/6] END max_depth=10, n_estimators=100;, score=0.881 total time= 1.9min
# [CV 1/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 1/5; 6/6] END max_depth=10, n_estimators=200;, score=0.832 total time= 3.8min
# [CV 2/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 2/5; 6/6] END max_depth=10, n_estimators=200;, score=0.783 total time= 3.8min
# [CV 3/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 3/5; 6/6] END max_depth=10, n_estimators=200;, score=0.859 total time= 3.8min
# [CV 4/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 4/5; 6/6] END max_depth=10, n_estimators=200;, score=0.859 total time= 3.9min
# [CV 5/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 5/5; 6/6] END max_depth=10, n_estimators=200;, score=0.874 total time= 3.9min
# Best Estimator: RandomForestClassifier(max_depth=10, n_estimators=200)
# Best F1 Score: 0.8416083333333333
# F1 Score on Test Data: 0.856
# CPU times: user 54min 45s, sys: 3.43 s, total: 54min 49s
# Wall time: 55min 3s

# %% [markdown]
# #### XGB

# %%
# %%time
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_estimators': [50, 100, 200],
              'max_depth': [5, 10,]}

# Create an XGBoost classifier
xgb = XGBClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(xgb, param_grid, scoring='f1')

# Fit the model to the training data
grid_search.fit(X_train, y_train)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
# Out:
# Best Estimator: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# Best F1 Score: 0.8657047350185536
# F1 Score on Test Data: 0.8897637795275591
# CPU times: user 4min 10s, sys: 1.19 s, total: 4min 11s
# Wall time: 2min 28s

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.96      0.83      0.89       136
#
#     accuracy                           1.00     85443
#    macro avg       0.98      0.92      0.94     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# #### Proceed with the model which shows the best result
# - Apply the best hyperparameter on the model
# - Predict on the test dataset

# %%
clf = grid_search.best_estimator_  #initialise the model with optimum hyperparameters
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
f1_test = f1_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print("F1 Score on Test Data:", f1_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.96      0.83      0.89       136
#
#     accuracy                           1.00     85443
#    macro avg       0.98      0.92      0.94     85443
# weighted avg       1.00      1.00      1.00     85443
#
# F1 Score on Test Data: 0.8897637795275591

# %%
# Plot feature importance
feature_importance = grid_search.best_estimator_.feature_importances_
for feature_name, importance in zip(X_test.columns, feature_importance):
    print(f"{feature_name}: {importance:.4f}")
# Out:
# Time: 0.0115
# V1: 0.0195
# V2: 0.0086
# V3: 0.0155
# V4: 0.0304
# V5: 0.0151
# V6: 0.0121
# V7: 0.2002
# V8: 0.0166
# V9: 0.0099
# V10: 0.0839
# V11: 0.0116
# V12: 0.0635
# V13: 0.0119
# V14: 0.2632
# V15: 0.0113
# V16: 0.0175
# V17: 0.0295
# V18: 0.0166
# V19: 0.0139
# V20: 0.0156
# V21: 0.0137
# V22: 0.0101
# V23: 0.0100
# V24: 0.0101
# V25: 0.0059
# V26: 0.0156
# V27: 0.0226
# V28: 0.0156
# Amount: 0.0186

# %%
print(clf)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### Print the important features of the best model to understand the dataset
# - This will not give much explanation on the already transformed dataset
# - But it will help us in understanding if the dataset is not PCA transformed

# %%
clf = grid_search.best_estimator_
var_imp = []
for i in clf.feature_importances_:
    var_imp.append(i)
print('Top var =', var_imp.index(np.sort(clf.feature_importances_)[-1])+1)
print('2nd Top var =', var_imp.index(np.sort(clf.feature_importances_)[-2])+1)
print('3rd Top var =', var_imp.index(np.sort(clf.feature_importances_)[-3])+1)

# Variable on Index-16 and Index-13 seems to be the top 2 variables
top_var_index = var_imp.index(np.sort(clf.feature_importances_)[-1])
second_top_var_index = var_imp.index(np.sort(clf.feature_importances_)[-2])

X_train_1 = X_train.to_numpy()[np.where(y_train==1.0)]
X_train_0 = X_train.to_numpy()[np.where(y_train==0.0)]

np.random.shuffle(X_train_0)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 6]

plt.scatter(X_train_1[:, top_var_index], X_train_1[:, second_top_var_index], label='Actual Class-1 Examples')
plt.scatter(X_train_0[:X_train_1.shape[0], top_var_index], X_train_0[:X_train_1.shape[0], second_top_var_index],
            label='Actual Class-0 Examples')
plt.legend()
# Out:
# Top var = 15
# 2nd Top var = 8
# 3rd Top var = 11

# %% [markdown]
# # Model building with balancing Classes
#
# ## Perform class balancing with :
# - Random Oversampling
# - SMOTE
# - ADASYN

# %%
#Over Sampling
# Define the random over-sampling strategy
oversample = RandomOverSampler(sampling_strategy='minority')

# Fit and apply the transform
X_over, y_over = oversample.fit_resample(X_train, y_train)

# Summarize the new class distribution
print('Resampled dataset shape %s' % Counter(y_over))
# Out:
# Resampled dataset shape Counter({0: 199008, 1: 199008})

# %% [markdown]
# ## Model Building - Random Oversampling
# - Build different models on the balanced dataset and see the result

# %% [markdown]
# #### perfom cross validation on the X_train & y_train to create:
# - X_train_cv
# - X_test_cv
# - y_train_cv
# - y_test_cv

# %%
y_over.value_counts()
# Out:
# 0    199008
# 1    199008
# Name: Class, dtype: int64

# %% [markdown]
# ### Random Oversampling

# %%
# %%time
#perform hyperparameter tuning
param_grid = {'C': [0.1, 1, 10, 100]}
cv = [3, 5]

# Create a logistic regression model
logreg = LogisticRegression(solver='lbfgs', max_iter=1000, random_state=42)

cv_scores = cross_val_score(logreg, X_over, y_over, cv=5)

print("Cross-validation scores:", cv_scores)
# Out:
# Cross-validation scores: [0.94120898 0.93556775 0.93689936 0.94177355 0.94181124]
# CPU times: user 38.5 s, sys: 10.5 s, total: 49 s
# Wall time: 29.6 s

# %%
from sklearn.model_selection import cross_val_predict

# Assuming you have a model called 'model' that has been cross-validated
# Make predictions on the test set using cross-validated model
y_pred_cv = cross_val_predict(logreg, X_test, y_test, cv=5)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.96      0.83      0.89       136
#
#     accuracy                           1.00     85443
#    macro avg       0.98      0.92      0.94     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### Similarly explore other algorithms on balanced dataset by building models like:
# - KNN
# - SVM
# - Decision Tree
# - Random Forest
# - XGBoost

# %% [markdown]
# #### KNN

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_neighbors': [3, 5,],
              'weights': ['uniform',]}

# Create a KNN classifier
knn = KNeighborsClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(knn, param_grid, scoring='f1', verbose=10)

# Fit the model to the training data
grid_search.fit(X_over, y_over)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 1/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.999 total time= 2.9min
# [CV 2/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 2/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.999 total time= 2.9min
# [CV 3/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 3/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.999 total time= 2.9min
# [CV 4/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 4/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.999 total time= 2.9min
# [CV 5/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 5/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.999 total time= 2.9min
# [CV 1/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 1/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.999 total time= 2.9min
# [CV 2/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 2/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.999 total time= 2.9min
# [CV 3/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 3/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.999 total time= 3.0min
# [CV 4/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 4/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.999 total time= 2.9min
# [CV 5/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 5/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.999 total time= 2.9min
# Best Estimator: KNeighborsClassifier(n_neighbors=3)
# Best F1 Score: 0.9993371664377664
# F1 Score on Test Data: 0.2436974789915966
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.28      0.21      0.24       136
#
#     accuracy                           1.00     85443
#    macro avg       0.64      0.61      0.62     85443
# weighted avg       1.00      1.00      1.00     85443
#
# CPU times: user 53min 4s, sys: 5.84 s, total: 53min 10s
# Wall time: 32min 58s

# %% [markdown]
# #### Random Forest

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_estimators': [50, 100],
              'max_depth': [5, 8]}

# Create a Random Forest classifier
rf = RandomForestClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(rf, param_grid, scoring='f1', verbose=10)

# Fit the model to the training data
grid_search.fit(X_over, y_over)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START max_depth=5, n_estimators=50................................
# [CV 1/5; 1/4] END .max_depth=5, n_estimators=50;, score=0.961 total time=  55.3s
# [CV 2/5; 1/4] START max_depth=5, n_estimators=50................................
# [CV 2/5; 1/4] END .max_depth=5, n_estimators=50;, score=0.955 total time=  41.2s
# [CV 3/5; 1/4] START max_depth=5, n_estimators=50................................
# [CV 3/5; 1/4] END .max_depth=5, n_estimators=50;, score=0.956 total time=  41.3s
# [CV 4/5; 1/4] START max_depth=5, n_estimators=50................................
# [CV 4/5; 1/4] END .max_depth=5, n_estimators=50;, score=0.955 total time=  43.2s
# [CV 5/5; 1/4] START max_depth=5, n_estimators=50................................
# [CV 5/5; 1/4] END .max_depth=5, n_estimators=50;, score=0.957 total time=  42.1s
# [CV 1/5; 2/4] START max_depth=5, n_estimators=100...............................
# [CV 1/5; 2/4] END max_depth=5, n_estimators=100;, score=0.957 total time= 1.4min
# [CV 2/5; 2/4] START max_depth=5, n_estimators=100...............................
# [CV 2/5; 2/4] END max_depth=5, n_estimators=100;, score=0.958 total time= 1.4min
# [CV 3/5; 2/4] START max_depth=5, n_estimators=100...............................
# [CV 3/5; 2/4] END max_depth=5, n_estimators=100;, score=0.954 total time= 1.3min
# [CV 4/5; 2/4] START max_depth=5, n_estimators=100...............................
# [CV 4/5; 2/4] END max_depth=5, n_estimators=100;, score=0.955 total time= 1.4min
# [CV 5/5; 2/4] START max_depth=5, n_estimators=100...............................
# [CV 5/5; 2/4] END max_depth=5, n_estimators=100;, score=0.957 total time= 1.3min
# [CV 1/5; 3/4] START max_depth=8, n_estimators=50................................
# [CV 1/5; 3/4] END .max_depth=8, n_estimators=50;, score=0.986 total time= 1.0min
# [CV 2/5; 3/4] START max_depth=8, n_estimators=50................................
# [CV 2/5; 3/4] END .max_depth=8, n_estimators=50;, score=0.982 total time=  58.4s
# [CV 3/5; 3/4] START max_depth=8, n_estimators=50................................
# [CV 3/5; 3/4] END .max_depth=8, n_estimators=50;, score=0.985 total time=  58.8s
# [CV 4/5; 3/4] START max_depth=8, n_estimators=50................................
# [CV 4/5; 3/4] END .max_depth=8, n_estimators=50;, score=0.984 total time=  57.7s
# [CV 5/5; 3/4] START max_depth=8, n_estimators=50................................
# [CV 5/5; 3/4] END .max_depth=8, n_estimators=50;, score=0.985 total time=  57.5s
# [CV 1/5; 4/4] START max_depth=8, n_estimators=100...............................
# [CV 1/5; 4/4] END max_depth=8, n_estimators=100;, score=0.985 total time= 2.0min
# [CV 2/5; 4/4] START max_depth=8, n_estimators=100...............................
# [CV 2/5; 4/4] END max_depth=8, n_estimators=100;, score=0.984 total time= 1.9min
# [CV 3/5; 4/4] START max_depth=8, n_estimators=100...............................
# [CV 3/5; 4/4] END max_depth=8, n_estimators=100;, score=0.985 total time= 1.9min
# [CV 4/5; 4/4] START max_depth=8, n_estimators=100...............................
# [CV 4/5; 4/4] END max_depth=8, n_estimators=100;, score=0.983 total time= 1.9min
# [CV 5/5; 4/4] START max_depth=8, n_estimators=100...............................
# [CV 5/5; 4/4] END max_depth=8, n_estimators=100;, score=0.982 total time= 2.0min
# Best Estimator: RandomForestClassifier(max_depth=8, n_estimators=50)
# Best F1 Score: 0.9845496146341233
# F1 Score on Test Data: 0.7327327327327328
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.62      0.90      0.73       136
#
#     accuracy                           1.00     85443
#    macro avg       0.81      0.95      0.87     85443
# weighted avg       1.00      1.00      1.00     85443
#
# CPU times: user 26min 12s, sys: 2.67 s, total: 26min 14s
# Wall time: 26min 28s

# %% [markdown]
# #### XGBoost

# %%
# %%time
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_estimators': [50, 100, 200],
              'max_depth': [5, 10,]}

# Create an XGBoost classifier
xgb = XGBClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(xgb, param_grid, scoring='f1')

# Fit the model to the training data
grid_search.fit(X_over, y_over)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))
# Out:
# Best Estimator: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# Best F1 Score: 0.9999346815094577
# F1 Score on Test Data: 0.8830188679245283
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.91      0.86      0.88       136
#
#     accuracy                           1.00     85443
#    macro avg       0.95      0.93      0.94     85443
# weighted avg       1.00      1.00      1.00     85443
#
# CPU times: user 7min 39s, sys: 2.19 s, total: 7min 41s
# Wall time: 4min 21s

# %% [markdown]
# ## Model Builing with SMOTE

# %% [markdown]
# #### Print the class distribution after applying SMOTE

# %%
import warnings
warnings.filterwarnings("ignore")


sm = SMOTE(random_state=0)
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)
# Artificial minority samples and corresponding minority labels from SMOTE are appended
# below X_train and y_train respectively
# So to exclusively get the artificial minority samples from SMOTE, we do
X_train_smote_1 = X_train_smote[X_train.shape[0]:]

X_train_1 = X_train.to_numpy()[np.where(y_train==1.0)]
X_train_0 = X_train.to_numpy()[np.where(y_train==0.0)]


plt.rcParams['figure.figsize'] = [20, 20]
fig = plt.figure()

plt.subplot(3, 1, 1)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.legend()

plt.subplot(3, 1, 2)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
# plt.scatter(X_train_smote_1[:X_train_1.shape[0], 0], X_train_smote_1[:X_train_1.shape[0], 1],
#             label='Artificial SMOTE Class-1 Examples')
plt.scatter(X_train_smote_1.iloc[:, 0], X_train_smote_1.iloc[:, 1],
            label='Artificial SMOTE Class-1 Examples')
plt.legend()

plt.subplot(3, 1, 3)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.scatter(X_train_0[:X_train_1.shape[0], 0], X_train_0[:X_train_1.shape[0], 1], label='Actual Class-0 Examples')
plt.legend()

# %%
#Implementing SMOTE
sm = SMOTE(random_state=0)
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)
print(y_train_smote.value_counts())

#perform hyperparameter tuning
param_grid = {'C': [0.1, 1, 10, 100]}
cv = [3, 5]

#print the evaluation result by choosing a evaluation metric
logreg = LogisticRegression(solver='lbfgs', max_iter=1000, random_state=42)

cv_scores = cross_val_score(logreg, X_train_smote, y_train_smote, cv=5)

#print the optimum value of hyperparameters
print("Cross-validation scores:", cv_scores)
# Out:
# 0    199008
# 1    199008
# Name: Class, dtype: int64
# Cross-validation scores: [0.96967489 0.96972476 0.96938558 0.97289047 0.97018957]

# %%
from sklearn.model_selection import cross_val_predict

# Assuming you have a model called 'model' that has been cross-validated
# Make predictions on the test set using cross-validated model
y_pred_cv = cross_val_predict(logreg, X_test, y_test, cv=5)

print(classification_report(y_test, y_pred_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.82      0.62      0.70       136
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.81      0.85     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ##### Build models on other algorithms to see the better performing on SMOTE

# %% [markdown]
# #### KNN

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_neighbors': [3, 5,],
              'weights': ['uniform']}

# Create a KNN classifier
knn = KNeighborsClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(knn, param_grid, scoring='f1', verbose=10)

# Fit the model to the training data
grid_search.fit(X_train_smote, y_train_smote)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 1/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.966 total time= 3.7min
# [CV 2/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 2/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.965 total time= 3.0min
# [CV 3/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 3/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.965 total time= 2.9min
# [CV 4/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 4/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.965 total time= 2.9min
# [CV 5/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 5/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.964 total time= 2.9min
# [CV 1/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 1/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.956 total time= 2.9min
# [CV 2/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 2/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.955 total time= 2.9min
# [CV 3/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 3/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.955 total time= 3.0min
# [CV 4/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 4/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.955 total time= 3.0min
# [CV 5/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 5/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.954 total time= 2.9min
# Best Estimator: KNeighborsClassifier(n_neighbors=3)
# Best F1 Score: 0.9648661073044478
# F1 Score on Test Data: 0.037238169123351435
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     85307
#            1       0.02      0.53      0.04       136
#
#     accuracy                           0.96     85443
#    macro avg       0.51      0.74      0.51     85443
# weighted avg       1.00      0.96      0.98     85443
#
# CPU times: user 53min 16s, sys: 6.32 s, total: 53min 23s
# Wall time: 34min 3s

# %% [markdown]
# #### Random Forest

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_estimators': [50, 100, 200],
              'max_depth': [5, 10]}

# Create a Random Forest classifier
rf = RandomForestClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(rf, param_grid, scoring='f1', verbose=10)

# Fit the model to the training data
grid_search.fit(X_train_smote, y_train_smote)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 1/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.966 total time= 1.2min
# [CV 2/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 2/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.965 total time= 1.1min
# [CV 3/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 3/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.966 total time= 1.2min
# [CV 4/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 4/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.966 total time= 1.1min
# [CV 5/5; 1/6] START max_depth=5, n_estimators=50................................
# [CV 5/5; 1/6] END .max_depth=5, n_estimators=50;, score=0.965 total time= 1.1min
# [CV 1/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 1/5; 2/6] END max_depth=5, n_estimators=100;, score=0.966 total time= 2.3min
# [CV 2/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 2/5; 2/6] END max_depth=5, n_estimators=100;, score=0.967 total time= 2.2min
# [CV 3/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 3/5; 2/6] END max_depth=5, n_estimators=100;, score=0.965 total time= 2.3min
# [CV 4/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 4/5; 2/6] END max_depth=5, n_estimators=100;, score=0.966 total time= 2.2min
# [CV 5/5; 2/6] START max_depth=5, n_estimators=100...............................
# [CV 5/5; 2/6] END max_depth=5, n_estimators=100;, score=0.964 total time= 2.3min
# [CV 1/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 1/5; 3/6] END max_depth=5, n_estimators=200;, score=0.965 total time= 4.6min
# [CV 2/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 2/5; 3/6] END max_depth=5, n_estimators=200;, score=0.966 total time= 4.5min
# [CV 3/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 3/5; 3/6] END max_depth=5, n_estimators=200;, score=0.966 total time= 4.5min
# [CV 4/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 4/5; 3/6] END max_depth=5, n_estimators=200;, score=0.965 total time= 4.5min
# [CV 5/5; 3/6] START max_depth=5, n_estimators=200...............................
# [CV 5/5; 3/6] END max_depth=5, n_estimators=200;, score=0.964 total time= 4.5min
# [CV 1/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 1/5; 4/6] END max_depth=10, n_estimators=50;, score=0.992 total time= 2.1min
# [CV 2/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 2/5; 4/6] END max_depth=10, n_estimators=50;, score=0.992 total time= 2.1min
# [CV 3/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 3/5; 4/6] END max_depth=10, n_estimators=50;, score=0.991 total time= 2.1min
# [CV 4/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 4/5; 4/6] END max_depth=10, n_estimators=50;, score=0.991 total time= 2.2min
# [CV 5/5; 4/6] START max_depth=10, n_estimators=50...............................
# [CV 5/5; 4/6] END max_depth=10, n_estimators=50;, score=0.991 total time= 2.1min
# [CV 1/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 1/5; 5/6] END max_depth=10, n_estimators=100;, score=0.991 total time= 4.2min
# [CV 2/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 2/5; 5/6] END max_depth=10, n_estimators=100;, score=0.992 total time= 4.2min
# [CV 3/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 3/5; 5/6] END max_depth=10, n_estimators=100;, score=0.990 total time= 4.1min
# [CV 4/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 4/5; 5/6] END max_depth=10, n_estimators=100;, score=0.992 total time= 4.2min
# [CV 5/5; 5/6] START max_depth=10, n_estimators=100..............................
# [CV 5/5; 5/6] END max_depth=10, n_estimators=100;, score=0.992 total time= 4.2min
# [CV 1/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 1/5; 6/6] END max_depth=10, n_estimators=200;, score=0.992 total time= 8.6min
# [CV 2/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 2/5; 6/6] END max_depth=10, n_estimators=200;, score=0.992 total time= 8.3min
# [CV 3/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 3/5; 6/6] END max_depth=10, n_estimators=200;, score=0.991 total time= 8.3min
# [CV 4/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 4/5; 6/6] END max_depth=10, n_estimators=200;, score=0.992 total time= 8.3min
# [CV 5/5; 6/6] START max_depth=10, n_estimators=200..............................
# [CV 5/5; 6/6] END max_depth=10, n_estimators=200;, score=0.992 total time= 8.2min
# Best Estimator: RandomForestClassifier(max_depth=10, n_estimators=200)
# Best F1 Score: 0.9918173267667992
# F1 Score on Test Data: 0.6833333333333333
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.55      0.90      0.68       136
#
#     accuracy                           1.00     85443
#    macro avg       0.77      0.95      0.84     85443
# weighted avg       1.00      1.00      1.00     85443
#
# CPU times: user 2h 2min 53s, sys: 8.37 s, total: 2h 3min 1s
# Wall time: 2h 3min 24s

# %% [markdown]
# #### XGBoost

# %%
# %%time
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_estimators': [50, 100, 150],
              'max_depth': [5, 8,]}

# Create an XGBoost classifier
xgb = XGBClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(xgb, param_grid, scoring='f1')

# Fit the model to the training data
grid_search.fit(X_train_smote, y_train_smote)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))
# Out:
# Best Estimator: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=150, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# Best F1 Score: 0.9998643466025847
# F1 Score on Test Data: 0.8169014084507041
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.78      0.85      0.82       136
#
#     accuracy                           1.00     85443
#    macro avg       0.89      0.93      0.91     85443
# weighted avg       1.00      1.00      1.00     85443
#
# CPU times: user 7min 52s, sys: 3.15 s, total: 7min 55s
# Wall time: 4min 31s

# %% [markdown]
# #### Proceed with the model which shows the best result
# - Apply the best hyperparameter on the model
# - Predict on the test dataset

# %%
clf = grid_search.best_estimator_  #initialise the model with optimum hyperparameters
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
f1_test = f1_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
print("F1 Score on Test Data:", f1_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.94      0.82      0.87       136
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.91      0.94     85443
# weighted avg       1.00      1.00      1.00     85443
#
# F1 Score on Test Data: 0.8740157480314961

# %%
# Plot feature importance
feature_importance = grid_search.best_estimator_.feature_importances_
for feature_name, importance in zip(X_test.columns, feature_importance):
    print(f"{feature_name}: {importance:.4f}")
# Out:
# Time: 0.0106
# V1: 0.0208
# V2: 0.0123
# V3: 0.0136
# V4: 0.0307
# V5: 0.0149
# V6: 0.0129
# V7: 0.1957
# V8: 0.0171
# V9: 0.0113
# V10: 0.0639
# V11: 0.0145
# V12: 0.0585
# V13: 0.0118
# V14: 0.2794
# V15: 0.0115
# V16: 0.0151
# V17: 0.0238
# V18: 0.0154
# V19: 0.0142
# V20: 0.0157
# V21: 0.0138
# V22: 0.0112
# V23: 0.0093
# V24: 0.0122
# V25: 0.0069
# V26: 0.0196
# V27: 0.0259
# V28: 0.0162
# Amount: 0.0211

# %% [markdown]
# ## Model Builing with ADASYN

# %% [markdown]
# ### Print the class distribution after applying ADASYN

# %%
import warnings
warnings.filterwarnings("ignore")

from imblearn import over_sampling

ada = over_sampling.ADASYN(random_state=0)
X_train_adasyn, y_train_adasyn = ada.fit_resample(X_train, y_train)
# Artificial minority samples and corresponding minority labels from ADASYN are appended
# below X_train and y_train respectively
# So to exclusively get the artificial minority samples from ADASYN, we do
X_train_adasyn_1 = X_train_adasyn[X_train.shape[0]:]

X_train_1 = X_train.to_numpy()[np.where(y_train==1.0)]
X_train_0 = X_train.to_numpy()[np.where(y_train==0.0)]



import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 20]
fig = plt.figure()

plt.subplot(3, 1, 1)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.legend()

plt.subplot(3, 1, 2)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
# plt.scatter(X_train_adasyn_1[:X_train_1.shape[0], 0], X_train_adasyn_1[:X_train_1.shape[0], 1],
#             label='Artificial ADASYN Class-1 Examples')
plt.scatter(X_train_adasyn_1.iloc[:, 0], X_train_adasyn_1.iloc[:, 1],
            label='Artificial ADASYN Class-1 Examples')
plt.legend()

plt.subplot(3, 1, 3)
plt.scatter(X_train_1[:, 0], X_train_1[:, 1], label='Actual Class-1 Examples')
plt.scatter(X_train_0[:X_train_1.shape[0], 0], X_train_0[:X_train_1.shape[0], 1], label='Actual Class-0 Examples')
plt.legend()

# %%
ada = ADASYN(random_state=0)
X_train_adasyn, y_train_adasyn = ada.fit_resample(X_train, y_train)
print(y_train_adasyn.value_counts())

#perform hyperparameter tuning
param_grid = {'C': [0.1, 1, 10, 100]}
cv = [3, 5]


#print the evaluation result by choosing a evaluation metric
logreg = LogisticRegression(solver='lbfgs', max_iter=1000, random_state=42)

cv_scores = cross_val_score(logreg, X_train_adasyn, y_train_adasyn, cv=5)

#print the optimum value of hyperparameters
print("Cross-validation scores:", cv_scores)
# Out:
# 0    199008
# 1    198960
# Name: Class, dtype: int64
# Cross-validation scores: [0.96152976 0.94739553 0.96681911 0.9704371  0.9640295 ]

# %%
# Assuming you have a model called 'model' that has been cross-validated
# Make predictions on the test set using cross-validated model
y_pred_cv = cross_val_predict(logreg, X_test, y_test, cv=5)

print(classification_report(y_test, y_pred_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.82      0.62      0.70       136
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.81      0.85     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ##### Build models on other algorithms to see the better performing on ADASYN

# %% [markdown]
# ### KNN

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_neighbors': [3, 5,],
              'weights': ['uniform']}

# Create a KNN classifier
knn = KNeighborsClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(knn, param_grid, scoring='f1',verbose=10)

# Fit the model to the training data
grid_search.fit(X_train_adasyn, y_train_adasyn)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 1/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.908 total time= 3.6min
# [CV 2/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 2/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.900 total time= 3.7min
# [CV 3/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 3/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.889 total time= 2.9min
# [CV 4/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 4/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.904 total time= 2.9min
# [CV 5/5; 1/2] START n_neighbors=3, weights=uniform..............................
# [CV 5/5; 1/2] END n_neighbors=3, weights=uniform;, score=0.893 total time= 2.9min
# [CV 1/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 1/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.902 total time= 2.9min
# [CV 2/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 2/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.892 total time= 2.9min
# [CV 3/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 3/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.882 total time= 2.9min
# [CV 4/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 4/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.896 total time= 2.9min
# [CV 5/5; 2/2] START n_neighbors=5, weights=uniform..............................
# [CV 5/5; 2/2] END n_neighbors=5, weights=uniform;, score=0.884 total time= 2.9min
# Best Estimator: KNeighborsClassifier(n_neighbors=3)
# Best F1 Score: 0.8987859231617694
# F1 Score on Test Data: 0.03712995484194682
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     85307
#            1       0.02      0.54      0.04       136
#
#     accuracy                           0.96     85443
#    macro avg       0.51      0.75      0.51     85443
# weighted avg       1.00      0.96      0.98     85443
#
# CPU times: user 53min 6s, sys: 5.89 s, total: 53min 11s
# Wall time: 34min 22s

# %% [markdown]
# ### Random Forest

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_estimators': [50, 100],}

# Create a Random Forest classifier
rf = RandomForestClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(rf, param_grid, scoring='f1',verbose=10)

# Fit the model to the training data
grid_search.fit(X_train_adasyn, y_train_adasyn)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START n_estimators=50.............................................
# [CV 1/5; 1/2] END ..............n_estimators=50;, score=0.989 total time= 3.1min
# [CV 2/5; 1/2] START n_estimators=50.............................................
# [CV 2/5; 1/2] END ..............n_estimators=50;, score=0.989 total time= 3.1min
# [CV 3/5; 1/2] START n_estimators=50.............................................
# [CV 3/5; 1/2] END ..............n_estimators=50;, score=0.992 total time= 3.0min
# [CV 4/5; 1/2] START n_estimators=50.............................................
# [CV 4/5; 1/2] END ..............n_estimators=50;, score=0.993 total time= 3.0min
# [CV 5/5; 1/2] START n_estimators=50.............................................
# [CV 5/5; 1/2] END ..............n_estimators=50;, score=0.994 total time= 2.9min
# [CV 1/5; 2/2] START n_estimators=100............................................
# [CV 1/5; 2/2] END .............n_estimators=100;, score=0.989 total time= 5.8min
# [CV 2/5; 2/2] START n_estimators=100............................................
# [CV 2/5; 2/2] END .............n_estimators=100;, score=0.989 total time= 5.9min
# [CV 3/5; 2/2] START n_estimators=100............................................
# [CV 3/5; 2/2] END .............n_estimators=100;, score=0.993 total time= 5.8min
# [CV 4/5; 2/2] START n_estimators=100............................................
# [CV 4/5; 2/2] END .............n_estimators=100;, score=0.994 total time= 5.8min
# [CV 5/5; 2/2] START n_estimators=100............................................

# %% [markdown]
# ### XGBoost

# %%
# %%time
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# Define the hyperparameter grid
param_grid = {'n_estimators': [50, 100, 200],
              'max_depth': [5, 10,]}

# Create an XGBoost classifier
xgb = XGBClassifier()

# Create GridSearchCV
grid_search = GridSearchCV(xgb, param_grid, scoring='f1')

# Fit the model to the training data
grid_search.fit(X_train_adasyn, y_train_adasyn)

# Get the best estimator and its corresponding score
best_estimator = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best Estimator:", best_estimator)
print("Best F1 Score:", best_score)

# Use the best estimator to predict on the test data
y_pred_test = best_estimator.predict(X_test)

# Calculate the F1 score on the test and train data
f1_test = f1_score(y_test, y_pred_test)

print("F1 Score on Test Data:", f1_test)
print(classification_report(y_test, y_pred_test))

# %% [markdown]
# ### Select the oversampling method which shows the best result on a model
# - Apply the best hyperparameter on the model
# - Predict on the test dataset

# %%
# perform the best oversampling method on X_train & y_train

clf = grid_search.best_estimator_  #initialise the model with optimum hyperparameters
clf.fit(X_train_adasyn, y_train_adasyn) # fit on the balanced dataset
y_pred_test = best_estimator.predict(X_test)
print(classification_report(y_test, y_pred_test))  #print the evaluation score on the X_test by choosing the best evaluation metric

# %% [markdown]
# ### Print the important features of the best model to understand the dataset

# %%
var_imp = []
for i in clf.feature_importances_:
    var_imp.append(i)
print('Top var =', var_imp.index(np.sort(clf.feature_importances_)[-1])+1)
print('2nd Top var =', var_imp.index(np.sort(clf.feature_importances_)[-2])+1)
print('3rd Top var =', var_imp.index(np.sort(clf.feature_importances_)[-3])+1)

# Variable on Index-13 and Index-9 seems to be the top 2 variables
top_var_index = var_imp.index(np.sort(clf.feature_importances_)[-1])
second_top_var_index = var_imp.index(np.sort(clf.feature_importances_)[-2])

X_train_1 = X_train.to_numpy()[np.where(y_train==1.0)]
X_train_0 = X_train.to_numpy()[np.where(y_train==0.0)]

np.random.shuffle(X_train_0)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 20]

plt.scatter(X_train_1[:, top_var_index], X_train_1[:, second_top_var_index], label='Actual Class-1 Examples')
plt.scatter(X_train_0[:X_train_1.shape[0], top_var_index], X_train_0[:X_train_1.shape[0], second_top_var_index],
            label='Actual Class-0 Examples')
plt.legend()

# %%
#### Print the FPR,TPR & select the best threshold from the roc curve

# %%
print('Train auc =', metrics.roc_auc_score(_________)
fpr, tpr, thresholds = metrics.roc_curve(_________)
threshold = thresholds[np.argmax(tpr-fpr)]
print(threshold)
